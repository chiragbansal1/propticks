# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('flats.csv')
df.sample(5)
# Out:
#                          property_name  \
# 3018         1 BHK Flat in Palam Vihar
# 3004         4 BHK Flat in DLF Phase 4
# 2082               2 BHK Flat in Sohna
# 3021  3 BHK Flat in Sector 103 Gurgaon
# 2847  2 BHK Flat in Sector 104 Gurgaon
#
#                                                    link  \
# 3018  https://www.99acres.com/1-bhk-bedroom-apartmen...
# 3004  https://www.99acres.com/4-bhk-bedroom-apartmen...
# 2082  https://www.99acres.com/2-bhk-bedroom-apartmen...
# 3021  https://www.99acres.com/3-bhk-bedroom-apartmen...
# 2847  https://www.99acres.com/2-bhk-bedroom-apartmen...
#
#                                    society       price            area  \
# 3018                   Palam Vihar Society      40 Lac  ₹ 8,602/sq.ft.
# 3004                    Chanderlok Society      90 Lac  ₹ 7,234/sq.ft.
# 2082                 Signature The Serenas      45 Lac  ₹ 8,474/sq.ft.
# 3021  Spire Woods Now Ananda by Alpha corp  1.25 Crore  ₹ 6,902/sq.ft.
# ...

# %%
df.shape
# Out:
# (3028, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3028 entries, 0 to 3027
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3028 non-null   object
#  1   link             3028 non-null   object
#  2   society          3027 non-null   object
#  3   price            3008 non-null   object
#  4   area             3015 non-null   object
#  5   areaWithType     3009 non-null   object
#  6   bedRoom          3009 non-null   object
#  7   bathroom         3009 non-null   object
#  8   balcony          3009 non-null   object
#  9   additionalRoom   1695 non-null   object
#  10  address          3003 non-null   object
#  11  floorNum         3007 non-null   object
#  12  facing           2128 non-null   object
#  13  agePossession    3008 non-null   object
#  14  nearbyLocations  2914 non-null   object
#  15  description      3009 non-null   object
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# property_name         0
# link                  0
# society               1
# price                20
# area                 13
# areaWithType         19
# bedRoom              19
# bathroom             19
# balcony              19
# additionalRoom     1333
# address              25
# floorNum             21
# facing              900
# agePossession        20
# nearbyLocations     114
# description          19
# furnishDetails      824
# features            433
# rating              351
# property_id          19
# dtype: int64
